# %% [markdown]
# # Stage Informatica - Data Anlysis and Intelligent System

# %% [markdown]
# ## Introduzione
#
# Argomenti trattati:
# - Big Data
# - Data sets
# - Data Analysis
# - Intelligent Systems

# %% [markdown]
# # Big Data
#
# ## Cosa sono i Big Data?
# - Quantità e flusso di dati così grande e complesso che le tradizionali tecnologie (SQL) di data managment non riescono a gestire
# - NoSQL databases sono emersi grazie alla loro capacità di gestire big data
#     - Fondamentale riuscire ad estrarre informazioni utili e prezione
# - Sistemi di intelligenza artificiale riscono a riconoscere pattern all'interno di grandi volumi di dati
#     - Esempio: Identificare abitudini di:
#         - Acquisto
#         - Visione e ascolto
#         - Interazione

# %% [markdown]
# ## Esempi
# ### Amazon Shopping
# **Dati**: Storico acquisti, Informazioni demografiche. <br>
# **Analisi**: Potenziali acquisti. <br>
# **Prodotto**: Plubbicità Ad-Hoc. <br>
# ### Uber
# **Dati**: Storico Corse, Traffico, Richieste. <br>
# **Analisi**: Picchi di domanda, Variazione della disponibilità dei driver. <br>
# **Prodotto**: Aggiustamento del prezzo della corsa. <br>
# ### Netflix
# **Dati**: Contenuti guardati, Interazione con la piattaforma. <br>
# **Analisi**: Titoli preferiti, Livello di attenzione, Pattern di visualizzazione. <br>
# **Prodotto**: Titotli da consigliare, Prodotto su cui investire. <br>

# %% [markdown]
# ## Web Data Mining
# Il Web è la più grande sorgente di informazione pubblicamente accessibile al mondo:
# - **Enorme quantità di dati**: in continua crescita, info su quasi qualunque cosa
# - **Eterogeneità del formato dei dati**: tabelle, pagine web (immagini, audio, video)
# - **Eterogeneità dell'informazione**
# - **Rumore e ridondanza** → (content mining), adattabilità del contenuto
# - **Dinamico**: info cambia nel tempo → monitoraggio cambiamenti
# - **Società virtuale**: forum, blog, siti di review, reti sociali → opinion mining, social network analysis
#
# ## Esempio:
# **[Twitter Analysis](http://bigdata.stratebi.com)** <br>
# **Problema**: Predizione gusti degli utenti. <br>
# **Misura di prestazione**: Percentuale tweet correttamente analizzati. <br>
# **Esperienza**: Utenti già profilati e relazioni già osservate. <br>

# %% [markdown]
# # Dataset
# Un dataset è una collezione di dati. Nel caso di dati tabulari, un set di dati corrisponde a una o più tabelle di un database, dove ogni colonna di una tabella rappresenta una particolare variabile, e ogni riga corrisponde a un dato record del set di dati in questione.

# %% [markdown]
# ## Risorse:
# - [Google Datasets](https://research.google/tools/datasets)
# - [Kaggle](https:www.kaggle.com)
#     - Cometizioni:
#         - Esempi di problemi reali
#         - Compenso economico per il vincitore
#         - Esempi:
#             - [H&M](https://www.kaggle.com/c/h-and-m-personalized-fashion-recommendations)
#             - [Titanic](https://www.kaggle.com/c/titanic)
#             - [G-Research Crypto Forecasting](https://www.kaggle.com/c/g-research-crypto-forecasting)
#             - [Feedback Prize - Evaluating Student Writing](https://www.kaggle.com/c/feedback-prize-2021)

# %% [markdown]
# # [Pandas](https://pandas.pydata.org) Tutorial

# %%
import pandas as pd

#Data Frame = 
df_mw = pd.read_csv("datasets/Minimum Wage Data.csv", encoding="Latin")
df_avocado.head()
# Out:
#    Year       State  State.Minimum.Wage  State.Minimum.Wage.2020.Dollars  \
# 0  1968     Alabama             0.00000                             0.00
# 1  1968      Alaska             2.10000                            15.61
# 2  1968     Arizona             0.46800                             3.48
# 3  1968    Arkansas             0.15625                             1.16
# 4  1968  California             1.65000                            12.26
#
#    Federal.Minimum.Wage  Federal.Minimum.Wage.2020.Dollars  \
# 0                  1.15                               8.55
# 1                  1.15                               8.55
# 2                  1.15                               8.55
# 3                  1.15                               8.55
# 4                  1.15                               8.55
#
#    Effective.Minimum.Wage  Effective.Minimum.Wage.2020.Dollars  CPI.Average  \
# 0                    1.15                                 8.55         34.8
# 1                    2.10                                15.61         34.8
# 2                    1.15                                 8.55         34.8
# 3                    1.15                                 8.55         34.8
# 4                    1.65                                12.26         34.8
#
#   Department.Of.Labor.Uncleaned.Data  Department.Of.Labor.Cleaned.Low.Value  \
# 0                                ...                                0.00000
# 1                                2.1                                2.10000
# 2                18.72 - 26.40/wk(b)                                0.46800
# 3                        1.25/day(b)                                0.15625
# 4                            1.65(b)                                1.65000
#
#    Department.Of.Labor.Cleaned.Low.Value.2020.Dollars  \
# 0                                               0.00
# 1                                              15.61
# 2                                               3.48
# 3                                               1.16
# 4                                              12.26
#
#    Department.Of.Labor.Cleaned.High.Value  \
# 0                                 0.00000
# 1                                 2.10000
# 2                                 0.66000
# 3                                 0.15625
# 4                                 1.65000
#
#    Department.Of.Labor.Cleaned.High.Value.2020.Dollars Footnote
# 0                                               0.00        NaN
# 1                                              15.61        NaN
# 2                                               4.91        (b)
# 3                                               1.16        (b)
# 4                                              12.26        (b)

# %%
df_avocado["AveragePrice"]
# Out:
# 0        1.33
# 1        1.35
# 2        0.93
# 3        1.08
# 4        1.28
#          ...
# 18244    1.63
# 18245    1.71
# 18246    1.87
# 18247    1.93
# 18248    1.62
# Name: AveragePrice, Length: 18249, dtype: float64

# %% [markdown]
# **Dividiamo il dataset**

# %%
df_boston = df_avocado[ df_avocado["region"] == "Boston" ]

# %%
df_boston.head()
# Out:
#      Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 208           0  2015-12-27          1.13     450816.39  3886.27  346964.70
# 209           1  2015-12-20          1.07     489802.88  4912.37  390100.99
# 210           2  2015-12-13          1.01     549945.76  4641.02  455362.38
# 211           3  2015-12-06          1.02     488679.31  5126.32  407520.22
# 212           4  2015-11-29          1.19     350559.81  3609.25  272719.08
#
#          4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 208  13952.56    86012.86    85913.60       99.26          0.0  conventional
# 209   5887.72    88901.80    88768.47      133.33          0.0  conventional
# 210    219.40    89722.96    89523.38      199.58          0.0  conventional
# 211    142.99    75889.78    75666.22      223.56          0.0  conventional
# 212    105.86    74125.62    73864.52      261.10          0.0  conventional
#
#      year  region
# 208  2015  Boston
# 209  2015  Boston
# 210  2015  Boston
# 211  2015  Boston
# 212  2015  Boston

# %% [markdown]
# Il dataframe viene spesso indicizzato da un elenento. <br>
#
# Nel nostro caso l'indice è senza significato, bisognerebbe trovare un dato che mette in relazione tutte le righe, per il nostro dataset si potrebbe usare la **data**! <br>

# %%
df_boston.index
# Out:
# Int64Index([  208,   209,   210,   211,   212,   213,   214,   215,   216,
#               217,
#             ...
#             17651, 17652, 17653, 17654, 17655, 17656, 17657, 17658, 17659,
#             17660],
#            dtype='int64', length=338)

# %%
df_boston.set_index("Date")
# Out:
#             Unnamed: 0  AveragePrice  Total Volume     4046       4225  \
# Date
# 2015-12-27           0          1.13     450816.39  3886.27  346964.70
# 2015-12-20           1          1.07     489802.88  4912.37  390100.99
# 2015-12-13           2          1.01     549945.76  4641.02  455362.38
# 2015-12-06           3          1.02     488679.31  5126.32  407520.22
# 2015-11-29           4          1.19     350559.81  3609.25  272719.08
# ...                ...           ...           ...      ...        ...
# 2018-02-04           7          1.83      28934.01     9.14    2504.27
# 2018-01-28           8          1.72      30846.35    14.65    1628.45
# 2018-01-21           9          1.82      26704.98    60.87    2647.48
# 2018-01-14          10          1.73      29468.36    12.77    2380.23
# 2018-01-07          11          1.91      30096.00    14.46    2704.48
#
#                 4770  Total Bags  Small Bags  Large Bags  XLarge Bags  \
# Date
# 2015-12-27  13952.56    86012.86    85913.60       99.26          0.0
# 2015-12-20   5887.72    88901.80    88768.47      133.33          0.0
# 2015-12-13    219.40    89722.96    89523.38      199.58          0.0
# 2015-12-06    142.99    75889.78    75666.22      223.56          0.0
# 2015-11-29    105.86    74125.62    73864.52      261.10          0.0
# ...              ...         ...         ...         ...          ...
# 2018-02-04      3.66    26416.94    20660.94     5756.00          0.0
# 2018-01-28      0.00    29203.25    27876.23     1327.02          0.0
# 2018-01-21      0.00    23996.63    21985.03     2011.60          0.0
# 2018-01-14      0.00    27075.36    23926.76     3148.60          0.0
# 2018-01-07      0.00    27377.06    25121.53     2255.53          0.0
#
#                     type  year  region
# Date
# 2015-12-27  conventional  2015  Boston
# 2015-12-20  conventional  2015  Boston
# 2015-12-13  conventional  2015  Boston
# 2015-12-06  conventional  2015  Boston
# 2015-11-29  conventional  2015  Boston
# ...                  ...   ...     ...
# 2018-02-04       organic  2018  Boston
# 2018-01-28       organic  2018  Boston
# 2018-01-21       organic  2018  Boston
# 2018-01-14       organic  2018  Boston
# 2018-01-07       organic  2018  Boston
#
# [338 rows x 13 columns]

# %%
df_boston.head()
# Out:
#      Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 208           0  2015-12-27          1.13     450816.39  3886.27  346964.70
# 209           1  2015-12-20          1.07     489802.88  4912.37  390100.99
# 210           2  2015-12-13          1.01     549945.76  4641.02  455362.38
# 211           3  2015-12-06          1.02     488679.31  5126.32  407520.22
# 212           4  2015-11-29          1.19     350559.81  3609.25  272719.08
#
#          4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 208  13952.56    86012.86    85913.60       99.26          0.0  conventional
# 209   5887.72    88901.80    88768.47      133.33          0.0  conventional
# 210    219.40    89722.96    89523.38      199.58          0.0  conventional
# 211    142.99    75889.78    75666.22      223.56          0.0  conventional
# 212    105.86    74125.62    73864.52      261.10          0.0  conventional
#
#      year  region
# 208  2015  Boston
# 209  2015  Boston
# 210  2015  Boston
# 211  2015  Boston
# 212  2015  Boston

# %% [markdown]
# Molte operazioni in Pandas ritornano un nuovo dataset, se esso non viene ridefinito in una variabile il contenuto verrà perso

# %%
df_boston = df_boston.set_index("Date") #inpace

# %%
df_boston.head()
# Out:
#             Unnamed: 0  AveragePrice  Total Volume     4046       4225  \
# Date
# 2015-12-27           0          1.13     450816.39  3886.27  346964.70
# 2015-12-20           1          1.07     489802.88  4912.37  390100.99
# 2015-12-13           2          1.01     549945.76  4641.02  455362.38
# 2015-12-06           3          1.02     488679.31  5126.32  407520.22
# 2015-11-29           4          1.19     350559.81  3609.25  272719.08
#
#                 4770  Total Bags  Small Bags  Large Bags  XLarge Bags  \
# Date
# 2015-12-27  13952.56    86012.86    85913.60       99.26          0.0
# 2015-12-20   5887.72    88901.80    88768.47      133.33          0.0
# 2015-12-13    219.40    89722.96    89523.38      199.58          0.0
# 2015-12-06    142.99    75889.78    75666.22      223.56          0.0
# 2015-11-29    105.86    74125.62    73864.52      261.10          0.0
#
#                     type  year  region
# Date
# 2015-12-27  conventional  2015  Boston
# 2015-12-20  conventional  2015  Boston
# 2015-12-13  conventional  2015  Boston
# 2015-12-06  conventional  2015  Boston
# 2015-11-29  conventional  2015  Boston

# %%
df_boston["AveragePrice"].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# Pandas non riconosce che sono date
#
# Riassegnare l'indice con un nuovo tipo -> Datetime

# %%
df_boston.index = pd.to_datetime(df_boston.index)
df_boston.head()
# Out:
#             Unnamed: 0  AveragePrice  Total Volume     4046       4225  \
# Date
# 2015-12-27           0          1.13     450816.39  3886.27  346964.70
# 2015-12-20           1          1.07     489802.88  4912.37  390100.99
# 2015-12-13           2          1.01     549945.76  4641.02  455362.38
# 2015-12-06           3          1.02     488679.31  5126.32  407520.22
# 2015-11-29           4          1.19     350559.81  3609.25  272719.08
#
#                 4770  Total Bags  Small Bags  Large Bags  XLarge Bags  \
# Date
# 2015-12-27  13952.56    86012.86    85913.60       99.26          0.0
# 2015-12-20   5887.72    88901.80    88768.47      133.33          0.0
# 2015-12-13    219.40    89722.96    89523.38      199.58          0.0
# 2015-12-06    142.99    75889.78    75666.22      223.56          0.0
# 2015-11-29    105.86    74125.62    73864.52      261.10          0.0
#
#                     type  year  region
# Date
# 2015-12-27  conventional  2015  Boston
# 2015-12-20  conventional  2015  Boston
# 2015-12-13  conventional  2015  Boston
# 2015-12-06  conventional  2015  Boston
# 2015-11-29  conventional  2015  Boston

# %%
df_boston["AveragePrice"].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# Media mobile
#
# In questo punto e le n precedenti qual'è la media?

# %%
df_boston["AveragePrice"].rolling(25).mean().plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df_boston.index
# Out:
# DatetimeIndex(['2015-12-27', '2015-12-20', '2015-12-13', '2015-12-06',
#                '2015-11-29', '2015-11-22', '2015-11-15', '2015-11-08',
#                '2015-11-01', '2015-10-25',
#                ...
#                '2018-03-11', '2018-03-04', '2018-02-25', '2018-02-18',
#                '2018-02-11', '2018-02-04', '2018-01-28', '2018-01-21',
#                '2018-01-14', '2018-01-07'],
#               dtype='datetime64[ns]', name='Date', length=338, freq=None)

# %% [markdown]
# I dati non sono ordinati correttamente!

# %%
df_boston.sort_index(inplace=True)
df_boston["AveragePrice"].rolling(25).mean().plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
#
albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'BaltimoreWashington',
#  'BaltimoreWashington',
#  'BaltimoreWashington',
#  'BaltimoreWashington',
#  'BaltimoreWashington',
#  'BaltimoreWashington',
#  'BaltimoreWashington',
#  'BaltimoreWashington',
#  'BaltimoreWashington',
#  'BaltimoreWashington',
#  'BaltimoreWashington',
#  'BaltimoreWashington',
#  'BaltimoreWashington',
#  'BaltimoreWashington',
#  'BaltimoreWashington',
#  'BaltimoreWashington',
#  'BaltimoreWashington',
#  'BaltimoreWashington',
#  'BaltimoreWashington',
#  'BaltimoreWashington',
#  'BaltimoreWashington',
#  'BaltimoreWashington',
#  'BaltimoreWashington',
#  'BaltimoreWashington',
#  'BaltimoreWashington',
#  'BaltimoreWashington',
#  'BaltimoreWashington',
#  'BaltimoreWashington',
#  'BaltimoreWashington',
#  'BaltimoreWashington',
#  'BaltimoreWashington',
#  'BaltimoreWashington',
#  'BaltimoreWashington',
#  'BaltimoreWashington',
#  'BaltimoreWashington',
#  'BaltimoreWashington',
#  'BaltimoreWashington',
#  'BaltimoreWashington',
#  'BaltimoreWashington',
#  'BaltimoreWashington',
#  'BaltimoreWashington',
#  'BaltimoreWashington',
#  'BaltimoreWashington',
#  'BaltimoreWashington',
#  'BaltimoreWashington',
#  'BaltimoreWashington',
#  'BaltimoreWashington',
#  'BaltimoreWashington',
#  'BaltimoreWashington',
#  'BaltimoreWashington',
#  'BaltimoreWashington',
#  'BaltimoreWashington',
#  'Boise',
#  'Boise',
#  'Boise',
#  'Boise',
#  'Boise',
#  'Boise',
#  'Boise',
#  'Boise',
#  'Boise',
#  'Boise',
#  'Boise',
#  'Boise',
#  'Boise',
#  'Boise',
#  'Boise',
#  'Boise',
#  'Boise',
#  'Boise',
#  'Boise',
#  'Boise',
#  'Boise',
#  'Boise',
#  'Boise',
#  'Boise',
#  'Boise',
#  'Boise',
#  'Boise',
#  'Boise',
#  'Boise',
#  'Boise',
#  'Boise',
#  'Boise',
#  'Boise',
#  'Boise',
#  'Boise',
#  'Boise',
#  'Boise',
#  'Boise',
#  'Boise',
#  'Boise',
#  'Boise',
#  'Boise',
#  'Boise',
#  'Boise',
#  'Boise',
#  'Boise',
#  'Boise',
#  'Boise',
#  'Boise',
#  'Boise',
#  'Boise',
#  'Boise',
#  'Boston',
#  'Boston',
#  'Boston',
#  'Boston',
#  'Boston',
#  'Boston',
#  'Boston',
#  'Boston',
#  'Boston',
#  'Boston',
#  'Boston',
#  'Boston',
#  'Boston',
#  'Boston',
#  'Boston',
#  'Boston',
#  'Boston',
#  'Boston',
#  'Boston',
#  'Boston',
#  'Boston',
#  'Boston',
#  'Boston',
#  'Boston',
#  'Boston',
#  'Boston',
#  'Boston',
#  'Boston',
#  'Boston',
#  'Boston',
#  'Boston',
#  'Boston',
#  'Boston',
#  'Boston',
#  'Boston',
#  'Boston',
#  'Boston',
#  'Boston',
#  'Boston',
#  'Boston',
#  'Boston',
#  'Boston',
#  'Boston',
#  'Boston',
#  'Boston',
#  'Boston',
#  'Boston',
#  'Boston',
#  'Boston',
#  'Boston',
#  'Boston',
#  'Boston',
#  'BuffaloRochester',
#  'BuffaloRochester',
#  'BuffaloRochester',
#  'BuffaloRochester',
#  'BuffaloRochester',
#  'BuffaloRochester',
#  'BuffaloRochester',
#  'BuffaloRochester',
#  'BuffaloRochester',
#  'BuffaloRochester',
#  'BuffaloRochester',
#  'BuffaloRochester',
#  'BuffaloRochester',
#  'BuffaloRochester',
#  'BuffaloRochester',
#  'BuffaloRochester',
#  'BuffaloRochester',
#  'BuffaloRochester',
#  'BuffaloRochester',
#  'BuffaloRochester',
#  'BuffaloRochester',
#  'BuffaloRochester',
#  'BuffaloRochester',
#  'BuffaloRochester',
#  'BuffaloRochester',
#  'BuffaloRochester',
#  'BuffaloRochester',
#  'BuffaloRochester',
#  'BuffaloRochester',
#  'BuffaloRochester',
#  'BuffaloRochester',
#  'BuffaloRochester',
#  'BuffaloRochester',
#  'BuffaloRochester',
#  'BuffaloRochester',
#  'BuffaloRochester',
#  'BuffaloRochester',
#  'BuffaloRochester',
#  'BuffaloRochester',
#  'BuffaloRochester',
#  'BuffaloRochester',
#  'BuffaloRochester',
#  'BuffaloRochester',
#  'BuffaloRochester',
#  'BuffaloRochester',
#  'BuffaloRochester',
#  'BuffaloRochester',
#  'BuffaloRochester',
#  'BuffaloRochester',
#  'BuffaloRochester',
#  'BuffaloRochester',
#  'BuffaloRochester',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'Charlotte',
#  'Charlotte',
#  'Charlotte',
#  'Charlotte',
#  'Charlotte',
#  'Charlotte',
#  'Charlotte',
#  'Charlotte',
#  'Charlotte',
#  'Charlotte',
#  'Charlotte',
#  'Charlotte',
#  'Charlotte',
#  'Charlotte',
#  'Charlotte',
#  'Charlotte',
#  'Charlotte',
#  'Charlotte',
#  'Charlotte',
#  'Charlotte',
#  'Charlotte',
#  'Charlotte',
#  'Charlotte',
#  'Charlotte',
#  'Charlotte',
#  'Charlotte',
#  'Charlotte',
#  'Charlotte',
#  'Charlotte',
#  'Charlotte',
#  'Charlotte',
#  'Charlotte',
#  'Charlotte',
#  'Charlotte',
#  'Charlotte',
#  'Charlotte',
#  'Charlotte',
#  'Charlotte',
#  'Charlotte',
#  'Charlotte',
#  'Charlotte',
#  'Charlotte',
#  'Charlotte',
#  'Charlotte',
#  'Charlotte',
#  'Charlotte',
#  'Charlotte',
#  'Charlotte',
#  'Charlotte',
#  'Charlotte',
#  'Charlotte',
#  'Charlotte',
#  'Chicago',
#  'Chicago',
#  'Chicago',
#  'Chicago',
#  'Chicago',
#  'Chicago',
#  'Chicago',
#  'Chicago',
#  'Chicago',
#  'Chicago',
#  'Chicago',
#  'Chicago',
#  'Chicago',
#  'Chicago',
#  'Chicago',
#  'Chicago',
#  'Chicago',
#  'Chicago',
#  'Chicago',
#  'Chicago',
#  'Chicago',
#  'Chicago',
#  'Chicago',
#  'Chicago',
#  'Chicago',
#  'Chicago',
#  'Chicago',
#  'Chicago',
#  'Chicago',
#  'Chicago',
#  'Chicago',
#  'Chicago',
#  'Chicago',
#  'Chicago',
#  'Chicago',
#  'Chicago',
#  'Chicago',
#  'Chicago',
#  'Chicago',
#  'Chicago',
#  'Chicago',
#  'Chicago',
#  'Chicago',
#  'Chicago',
#  'Chicago',
#  'Chicago',
#  'Chicago',
#  'Chicago',
#  'Chicago',
#  'Chicago',
#  'Chicago',
#  'Chicago',
#  'CincinnatiDayton',
#  'CincinnatiDayton',
#  'CincinnatiDayton',
#  'CincinnatiDayton',
#  'CincinnatiDayton',
#  'CincinnatiDayton',
#  'CincinnatiDayton',
#  'CincinnatiDayton',
#  'CincinnatiDayton',
#  'CincinnatiDayton',
#  'CincinnatiDayton',
#  'CincinnatiDayton',
#  'CincinnatiDayton',
#  'CincinnatiDayton',
#  'CincinnatiDayton',
#  'CincinnatiDayton',
#  'CincinnatiDayton',
#  'CincinnatiDayton',
#  'CincinnatiDayton',
#  'CincinnatiDayton',
#  'CincinnatiDayton',
#  'CincinnatiDayton',
#  'CincinnatiDayton',
#  'CincinnatiDayton',
#  'CincinnatiDayton',
#  'CincinnatiDayton',
#  'CincinnatiDayton',
#  'CincinnatiDayton',
#  'CincinnatiDayton',
#  'CincinnatiDayton',
#  'CincinnatiDayton',
#  'CincinnatiDayton',
#  'CincinnatiDayton',
#  'CincinnatiDayton',
#  'CincinnatiDayton',
#  'CincinnatiDayton',
#  'CincinnatiDayton',
#  'CincinnatiDayton',
#  'CincinnatiDayton',
#  'CincinnatiDayton',
#  'CincinnatiDayton',
#  'CincinnatiDayton',
#  'CincinnatiDayton',
#  'CincinnatiDayton',
#  'CincinnatiDayton',
#  'CincinnatiDayton',
#  'CincinnatiDayton',
#  'CincinnatiDayton',
#  'CincinnatiDayton',
#  'CincinnatiDayton',
#  'CincinnatiDayton',
#  'CincinnatiDayton',
#  'Columbus',
#  'Columbus',
#  'Columbus',
#  'Columbus',
#  'Columbus',
#  'Columbus',
#  'Columbus',
#  'Columbus',
#  'Columbus',
#  'Columbus',
#  'Columbus',
#  'Columbus',
#  'Columbus',
#  'Columbus',
#  'Columbus',
#  'Columbus',
#  'Columbus',
#  'Columbus',
#  'Columbus',
#  'Columbus',
#  'Columbus',
#  'Columbus',
#  'Columbus',
#  'Columbus',
#  'Columbus',
#  'Columbus',
#  'Columbus',
#  'Columbus',
#  'Columbus',
#  'Columbus',
#  'Columbus',
#  'Columbus',
#  'Columbus',
#  'Columbus',
#  'Columbus',
#  'Columbus',
#  'Columbus',
#  'Columbus',
#  'Columbus',
#  'Columbus',
#  'Columbus',
#  'Columbus',
#  'Columbus',
#  'Columbus',
#  'Columbus',
#  'Columbus',
#  'Columbus',
#  'Columbus',
#  'Columbus',
#  'Columbus',
#  'Columbus',
#  'Columbus',
#  'DallasFtWorth',
#  'DallasFtWorth',
#  'DallasFtWorth',
#  'DallasFtWorth',
#  'DallasFtWorth',
#  'DallasFtWorth',
#  'DallasFtWorth',
#  'DallasFtWorth',
#  'DallasFtWorth',
#  'DallasFtWorth',
#  'DallasFtWorth',
#  'DallasFtWorth',
#  'DallasFtWorth',
#  'DallasFtWorth',
#  'DallasFtWorth',
#  'DallasFtWorth',
#  'DallasFtWorth',
#  'DallasFtWorth',
#  'DallasFtWorth',
#  'DallasFtWorth',
#  'DallasFtWorth',
#  'DallasFtWorth',
#  'DallasFtWorth',
#  'DallasFtWorth',
#  'DallasFtWorth',
#  'DallasFtWorth',
#  'DallasFtWorth',
#  'DallasFtWorth',
#  'DallasFtWorth',
#  'DallasFtWorth',
#  'DallasFtWorth',
#  'DallasFtWorth',
#  'DallasFtWorth',
#  'DallasFtWorth',
#  'DallasFtWorth',
#  'DallasFtWorth',
#  'DallasFtWorth',
#  'DallasFtWorth',
#  'DallasFtWorth',
#  'DallasFtWorth',
#  'DallasFtWorth',
#  'DallasFtWorth',
#  'DallasFtWorth',
#  'DallasFtWorth',
#  'DallasFtWorth',
#  'DallasFtWorth',
#  'DallasFtWorth',
#  'DallasFtWorth',
#  'DallasFtWorth',
#  'DallasFtWorth',
#  'DallasFtWorth',
#  'DallasFtWorth',
#  'Denver',
#  'Denver',
#  'Denver',
#  'Denver',
#  'Denver',
#  'Denver',
#  'Denver',
#  'Denver',
#  'Denver',
#  'Denver',
#  'Denver',
#  'Denver',
#  'Denver',
#  'Denver',
#  'Denver',
#  'Denver',
#  'Denver',
#  'Denver',
#  'Denver',
#  'Denver',
#  'Denver',
#  'Denver',
#  'Denver',
#  'Denver',
#  'Denver',
#  'Denver',
#  'Denver',
#  'Denver',
#  'Denver',
#  'Denver',
#  'Denver',
#  'Denver',
#  'Denver',
#  'Denver',
#  'Denver',
#  'Denver',
#  'Denver',
#  'Denver',
#  'Denver',
#  'Denver',
#  'Denver',
#  'Denver',
#  'Denver',
#  'Denver',
#  'Denver',
#  'Denver',
#  'Denver',
#  'Denver',
#  'Denver',
#  'Denver',
#  'Denver',
#  'Denver',
#  'Detroit',
#  'Detroit',
#  'Detroit',
#  'Detroit',
#  'Detroit',
#  'Detroit',
#  'Detroit',
#  'Detroit',
#  'Detroit',
#  'Detroit',
#  'Detroit',
#  'Detroit',
#  'Detroit',
#  'Detroit',
#  'Detroit',
#  'Detroit',
#  'Detroit',
#  'Detroit',
#  'Detroit',
#  'Detroit',
#  'Detroit',
#  'Detroit',
#  'Detroit',
#  'Detroit',
#  'Detroit',
#  'Detroit',
#  'Detroit',
#  'Detroit',
#  'Detroit',
#  'Detroit',
#  'Detroit',
#  'Detroit',
#  'Detroit',
#  'Detroit',
#  'Detroit',
#  'Detroit',
#  'Detroit',
#  'Detroit',
#  'Detroit',
#  'Detroit',
#  'Detroit',
#  'Detroit',
#  'Detroit',
#  'Detroit',
#  'Detroit',
#  'Detroit',
#  'Detroit',
#  'Detroit',
#  'Detroit',
#  'Detroit',
#  'Detroit',
#  'Detroit',
#  'GrandRapids',
#  'GrandRapids',
#  'GrandRapids',
#  'GrandRapids',
#  'GrandRapids',
#  'GrandRapids',
#  'GrandRapids',
#  'GrandRapids',
#  'GrandRapids',
#  'GrandRapids',
#  'GrandRapids',
#  'GrandRapids',
#  'GrandRapids',
#  'GrandRapids',
#  'GrandRapids',
#  'GrandRapids',
#  'GrandRapids',
#  'GrandRapids',
#  'GrandRapids',
#  'GrandRapids',
#  'GrandRapids',
#  'GrandRapids',
#  'GrandRapids',
#  'GrandRapids',
#  'GrandRapids',
#  'GrandRapids',
#  'GrandRapids',
#  'GrandRapids',
#  'GrandRapids',
#  'GrandRapids',
#  'GrandRapids',
#  'GrandRapids',
#  'GrandRapids',
#  'GrandRapids',
#  'GrandRapids',
#  'GrandRapids',
#  'GrandRapids',
#  'GrandRapids',
#  'GrandRapids',
#  'GrandRapids',
#  'GrandRapids',
#  'GrandRapids',
#  'GrandRapids',
#  'GrandRapids',
#  'GrandRapids',
#  'GrandRapids',
#  'GrandRapids',
#  'GrandRapids',
#  'GrandRapids',
#  'GrandRapids',
#  'GrandRapids',
#  'GrandRapids',
#  'GreatLakes',
#  'GreatLakes',
#  'GreatLakes',
#  'GreatLakes',
#  'GreatLakes',
#  'GreatLakes',
#  'GreatLakes',
#  'GreatLakes',
#  'GreatLakes',
#  'GreatLakes',
#  'GreatLakes',
#  'GreatLakes',
#  'GreatLakes',
#  'GreatLakes',
#  'GreatLakes',
#  'GreatLakes',
#  'GreatLakes',
#  'GreatLakes',
#  'GreatLakes',
#  'GreatLakes',
#  'GreatLakes',
#  'GreatLakes',
#  'GreatLakes',
#  'GreatLakes',
#  'GreatLakes',
#  'GreatLakes',
#  'GreatLakes',
#  'GreatLakes',
#  'GreatLakes',
#  'GreatLakes',
#  'GreatLakes',
#  'GreatLakes',
#  'GreatLakes',
#  'GreatLakes',
#  'GreatLakes',
#  'GreatLakes',
#  'GreatLakes',
#  'GreatLakes',
#  'GreatLakes',
#  'GreatLakes',
#  'GreatLakes',
#  'GreatLakes',
#  'GreatLakes',
#  'GreatLakes',
#  'GreatLakes',
#  'GreatLakes',
#  'GreatLakes',
#  'GreatLakes',
#  'GreatLakes',
#  'GreatLakes',
#  'GreatLakes',
#  'GreatLakes',
#  'HarrisburgScranton',
#  'HarrisburgScranton',
#  'HarrisburgScranton',
#  'HarrisburgScranton',
#  'HarrisburgScranton',
#  'HarrisburgScranton',
#  'HarrisburgScranton',
#  'HarrisburgScranton',
#  'HarrisburgScranton',
#  'HarrisburgScranton',
#  'HarrisburgScranton',
#  'HarrisburgScranton',
#  'HarrisburgScranton',
#  'HarrisburgScranton',
#  'HarrisburgScranton',
#  'HarrisburgScranton',
#  'HarrisburgScranton',
#  'HarrisburgScranton',
#  'HarrisburgScranton',
#  'HarrisburgScranton',
#  'HarrisburgScranton',
#  'HarrisburgScranton',
#  'HarrisburgScranton',
#  'HarrisburgScranton',
#  'HarrisburgScranton',
#  'HarrisburgScranton',
#  'HarrisburgScranton',
#  'HarrisburgScranton',
#  'HarrisburgScranton',
#  'HarrisburgScranton',
#  'HarrisburgScranton',
#  'HarrisburgScranton',
#  'HarrisburgScranton',
#  'HarrisburgScranton',
#  'HarrisburgScranton',
#  'HarrisburgScranton',
#  'HarrisburgScranton',
#  'HarrisburgScranton',
#  'HarrisburgScranton',
#  'HarrisburgScranton',
#  'HarrisburgScranton',
#  'HarrisburgScranton',
#  'HarrisburgScranton',
#  'HarrisburgScranton',
#  'HarrisburgScranton',
#  'HarrisburgScranton',
#  'HarrisburgScranton',
#  'HarrisburgScranton',
#  'HarrisburgScranton',
#  'HarrisburgScranton',
#  'HarrisburgScranton',
#  'HarrisburgScranton',
#  'HartfordSpringfield',
#  'HartfordSpringfield',
#  'HartfordSpringfield',
#  'HartfordSpringfield',
#  'HartfordSpringfield',
#  'HartfordSpringfield',
#  'HartfordSpringfield',
#  'HartfordSpringfield',
#  'HartfordSpringfield',
#  'HartfordSpringfield',
#  'HartfordSpringfield',
#  'HartfordSpringfield',
#  'HartfordSpringfield',
#  'HartfordSpringfield',
#  'HartfordSpringfield',
#  'HartfordSpringfield',
#  'HartfordSpringfield',
#  'HartfordSpringfield',
#  'HartfordSpringfield',
#  'HartfordSpringfield',
#  'HartfordSpringfield',
#  'HartfordSpringfield',
#  'HartfordSpringfield',
#  'HartfordSpringfield',
#  'HartfordSpringfield',
#  'HartfordSpringfield',
#  'HartfordSpringfield',
#  'HartfordSpringfield',
#  'HartfordSpringfield',
#  'HartfordSpringfield',
#  'HartfordSpringfield',
#  'HartfordSpringfield',
#  'HartfordSpringfield',
#  'HartfordSpringfield',
#  'HartfordSpringfield',
#  'HartfordSpringfield',
#  'HartfordSpringfield',
#  'HartfordSpringfield',
#  'HartfordSpringfield',
#  'HartfordSpringfield',
#  'HartfordSpringfield',
#  'HartfordSpringfield',
#  'HartfordSpringfield',
#  'HartfordSpringfield',
#  'HartfordSpringfield',
#  'HartfordSpringfield',
#  'HartfordSpringfield',
#  'HartfordSpringfield',
#  'HartfordSpringfield',
#  'HartfordSpringfield',
#  'HartfordSpringfield',
#  'HartfordSpringfield',
#  'Houston',
#  'Houston',
#  'Houston',
#  'Houston',
#  'Houston',
#  'Houston',
#  'Houston',
#  'Houston',
#  'Houston',
#  'Houston',
#  'Houston',
#  'Houston',
#  'Houston',
#  'Houston',
#  'Houston',
#  'Houston',
#  'Houston',
#  'Houston',
#  'Houston',
#  'Houston',
#  'Houston',
#  'Houston',
#  'Houston',
#  'Houston',
#  'Houston',
#  'Houston',
#  'Houston',
#  'Houston',
#  'Houston',
#  'Houston',
#  'Houston',
#  'Houston',
#  'Houston',
#  'Houston',
#  'Houston',
#  'Houston',
#  'Houston',
#  'Houston',
#  'Houston',
#  'Houston',
#  'Houston',
#  'Houston',
#  'Houston',
#  'Houston',
#  'Houston',
#  'Houston',
#  'Houston',
#  'Houston',
#  'Houston',
#  'Houston',
#  'Houston',
#  'Houston',
#  'Indianapolis',
#  'Indianapolis',
#  'Indianapolis',
#  'Indianapolis',
#  'Indianapolis',
#  'Indianapolis',
#  'Indianapolis',
#  'Indianapolis',
#  'Indianapolis',
#  'Indianapolis',
#  'Indianapolis',
#  'Indianapolis',
#  ...]

# %%
set(df_avocado["region"].values.tolist())
#set restituisce un array
# Out:
# {'Albany',
#  'Atlanta',
#  'BaltimoreWashington',
#  'Boise',
#  'Boston',
#  'BuffaloRochester',
#  'California',
#  'Charlotte',
#  'Chicago',
#  'CincinnatiDayton',
#  'Columbus',
#  'DallasFtWorth',
#  'Denver',
#  'Detroit',
#  'GrandRapids',
#  'GreatLakes',
#  'HarrisburgScranton',
#  'HartfordSpringfield',
#  'Houston',
#  'Indianapolis',
#  'Jacksonville',
#  'LasVegas',
#  'LosAngeles',
#  'Louisville',
#  'MiamiFtLauderdale',
#  'Midsouth',
#  'Nashville',
#  'NewOrleansMobile',
#  'NewYork',
#  'Northeast',
#  'NorthernNewEngland',
#  'Orlando',
#  'Philadelphia',
#  'PhoenixTucson',
#  'Pittsburgh',
#  'Plains',
#  'Portland',
#  'RaleighGreensboro',
#  'RichmondNorfolk',
#  'Roanoke',
#  'Sacramento',
#  'SanDiego',
#  'SanFrancisco',
#  'Seattle',
#  'SouthCarolina',
#  'SouthCentral',
#  'Southeast',
#  'Spokane',
#  'StLouis',
#  'Syracuse',
#  'Tampa',
#  'TotalUS',
#  'West',
#  'WestTexNewMexico'}

# %%
list(set(df_avocado["region"].values.tolist()))
# Out:
# ['Charlotte',
#  'Denver',
#  'WestTexNewMexico',
#  'NewYork',
#  'California',
#  'DallasFtWorth',
#  'Chicago',
#  'Portland',
#  'Spokane',
#  'Columbus',
#  'SanDiego',
#  'Jacksonville',
#  'Seattle',
#  'LasVegas',
#  'Detroit',
#  'PhoenixTucson',
#  'Southeast',
#  'GrandRapids',
#  'HarrisburgScranton',
#  'Northeast',
#  'Orlando',
#  'West',
#  'MiamiFtLauderdale',
#  'Sacramento',
#  'HartfordSpringfield',
#  'TotalUS',
#  'Syracuse',
#  'Tampa',
#  'GreatLakes',
#  'Midsouth',
#  'Philadelphia',
#  'Nashville',
#  'SouthCentral',
#  'StLouis',
#  'LosAngeles',
#  'RaleighGreensboro',
#  'SouthCarolina',
#  'Pittsburgh',
#  'NewOrleansMobile',
#  'NorthernNewEngland',
#  'Albany',
#  'RichmondNorfolk',
#  'BaltimoreWashington',
#  'SanFrancisco',
#  'CincinnatiDayton',
#  'Boise',
#  'BuffaloRochester',
#  'Houston',
#  'Indianapolis',
#  'Louisville',
#  'Roanoke',
#  'Atlanta',
#  'Plains',
#  'Boston']

# %%
df_avocado["region"].unique()
# Out:
# array(['Albany', 'Atlanta', 'BaltimoreWashington', 'Boise', 'Boston',
#        'BuffaloRochester', 'California', 'Charlotte', 'Chicago',
#        'CincinnatiDayton', 'Columbus', 'DallasFtWorth', 'Denver',
#        'Detroit', 'GrandRapids', 'GreatLakes', 'HarrisburgScranton',
#        'HartfordSpringfield', 'Houston', 'Indianapolis', 'Jacksonville',
#        'LasVegas', 'LosAngeles', 'Louisville', 'MiamiFtLauderdale',
#        'Midsouth', 'Nashville', 'NewOrleansMobile', 'NewYork',
#        'Northeast', 'NorthernNewEngland', 'Orlando', 'Philadelphia',
#        'PhoenixTucson', 'Pittsburgh', 'Plains', 'Portland',
#        'RaleighGreensboro', 'RichmondNorfolk', 'Roanoke', 'Sacramento',
#        'SanDiego', 'SanFrancisco', 'Seattle', 'SouthCarolina',
#        'SouthCentral', 'Southeast', 'Spokane', 'StLouis', 'Syracuse',
#        'Tampa', 'TotalUS', 'West', 'WestTexNewMexico'], dtype=object)

# %%
df_avocado = pd.read_csv("datasets/avocado.csv")
df_avocado = df_avocado[df_avocado["type"]=="organic"]
df_avocado.sort_values(by="Date", ascending=True, inplace=True) #Possiamo ordinare anche per colonna

graph_df = pd.DataFrame()

for region in df_avocado["region"].unique():
    print(region)
    region_df = df_avocado[df_avocado["region"] == region]
    region_df.set_index("Date", inplace=True)
    region_df.sort_index(inplace=True)
    region_df[f"_{region}_price25ma"] = region_df["AveragePrice"].rolling(25).mean()
    
    if graph_df.empty:
        graph_df = region_df[[f"_{region}_price25ma"]] #.. , [], []
    else:
        graph_df = graph_df.join(region_df[f"_{region}_price25ma"])
# Out:
# California
# LasVegas
# PhoenixTucson
# BuffaloRochester
# Spokane
# LosAngeles
# Philadelphia
# Boston
# StLouis
# Louisville
# Orlando
# Southeast
# Boise
# MiamiFtLauderdale
# NorthernNewEngland
# BaltimoreWashington
# Midsouth
# Tampa
# West
# Northeast
# Atlanta
# Nashville
# TotalUS
# Syracuse
# WestTexNewMexico
# Jacksonville
# Charlotte
# Sacramento
# GrandRapids
# Roanoke
# Denver
# SanDiego
# GreatLakes
# RichmondNorfolk
# DallasFtWorth
# SanFrancisco
# HarrisburgScranton
# Pittsburgh
# RaleighGreensboro
# Seattle
# HartfordSpringfield
# Portland
# CincinnatiDayton
# SouthCarolina
# Houston
# Chicago
# Plains
# Indianapolis
# SouthCentral
# Columbus
# Albany
# Detroit
# NewOrleansMobile
# NewYork
# /var/folders/lr/d8nq9v9x525g290h3kqjrbgw0000gn/T/ipykernel_5876/455009957.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   region_df[f"_{region}_price25ma"] = region_df["AveragePrice"].rolling(25).mean()

# %%
graph_df.tail()
# Out:
#             _California_price25ma  _LasVegas_price25ma  \
# Date
# 2018-02-25                 1.9128               1.9120
# 2018-03-04                 1.8876               1.8748
# 2018-03-11                 1.8636               1.8440
# 2018-03-18                 1.8516               1.8204
# 2018-03-25                 1.8364               1.7968
#
#             _PhoenixTucson_price25ma  _BuffaloRochester_price25ma  \
# Date
# 2018-02-25                    1.7468                       1.2912
# 2018-03-04                    1.7404                       1.2744
# 2018-03-11                    1.7324                       1.2652
# 2018-03-18                    1.7216                       1.2560
# 2018-03-25                    1.7104                       1.2416
#
#             _Spokane_price25ma  _LosAngeles_price25ma  \
# Date
# 2018-02-25              2.1544                 1.9024
# 2018-03-04              2.1040                 1.8656
# 2018-03-11              2.0552                 1.8284
# 2018-03-18              2.0012                 1.8160
# 2018-03-25              1.9496                 1.8016
#
#             _Philadelphia_price25ma  _Boston_price25ma  _StLouis_price25ma  \
# Date
# 2018-02-25                   1.6324             1.7636              1.9240
# 2018-03-04                   1.6260             1.7708              1.8868
# 2018-03-11                   1.6300             1.7824              1.8468
# 2018-03-18                   1.6304             1.7932              1.8192
# 2018-03-25                   1.6256             1.7984              1.7976
#
#             _Louisville_price25ma  ...  _Houston_price25ma  \
# Date                               ...
# 2018-02-25                 1.7044  ...              1.6132
# 2018-03-04                 1.6816  ...              1.5960
# 2018-03-11                 1.6508  ...              1.5696
# 2018-03-18                 1.6176  ...              1.5360
# 2018-03-25                 1.5844  ...              1.5128
#
#             _Chicago_price25ma  _Plains_price25ma  _Indianapolis_price25ma  \
# Date
# 2018-02-25              1.8160             1.8116                   1.4928
# 2018-03-04              1.8024             1.7900                   1.4744
# 2018-03-11              1.7836             1.7672                   1.4540
# 2018-03-18              1.7732             1.7452                   1.4320
# 2018-03-25              1.7672             1.7232                   1.4160
#
#             _SouthCentral_price25ma  _Columbus_price25ma  _Albany_price25ma  \
# Date
# 2018-02-25                   1.5728               1.6064             1.5112
# 2018-03-04                   1.5592               1.5804             1.4992
# 2018-03-11                   1.5400               1.5496             1.5044
# 2018-03-18                   1.5204               1.5088             1.5140
# 2018-03-25                   1.5072               1.4848             1.5188
#
#             _Detroit_price25ma  _NewOrleansMobile_price25ma  \
# Date
# 2018-02-25              1.4980                       1.5384
# 2018-03-04              1.4692                       1.5288
# 2018-03-11              1.4444                       1.5076
# 2018-03-18              1.4092                       1.4860
# 2018-03-25              1.3964                       1.4616
#
#             _NewYork_price25ma
# Date
# 2018-02-25              1.9308
# 2018-03-04              1.9156
# 2018-03-11              1.9092
# 2018-03-18              1.8948
# 2018-03-25              1.8876
#
# [5 rows x 54 columns]

# %%
graph_df.plot(figsize=(8,5), legend=False)
# Out:
# <AxesSubplot:xlabel='Date'>
