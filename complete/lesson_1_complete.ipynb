# %% [markdown]
# # Stage Informatica - Data Anlysis and Intelligent System

# %% [markdown]
# ## Introduzione
#
# In risposta all'incremento esponenzile negli ultimi anni dell'afflusso di dati, l'ambito Data Science è stato completamente rivoluzionato nell'ultimo decennio. Questa disciplina è stata portata avanti da persone provenienti da una vasta gamma di campi - statistica, fisica, informatica, design e molti altri - l'ambito Data Science rappresenta il desiderio collettivo di comprendere e sfruttare l'abbondanza di dati che ci circonda.
#
# Argomenti trattati:
# - Big Data
# - Data Analysis
# - Intelligent Systems

# %% [markdown]
# # Big Data
#
# ## Cosa sono i Big Data?
# - Quantità e flusso di dati così grande e complesso che le tradizionali tecnologie (SQL) di data managment non riescono a gestire
# - NoSQL databases sono emersi grazie alla loro capacità di gestire big data
#     - Fondamentale riuscire ad estrarre informazioni utili e prezione
# - Sistemi di intelligenza artificiale riscono a riconoscere pattern all'interno di grandi volumi di dati
#     - Esempio: Identificare abitudini di:
#         - Acquisto
#         - Visione e ascolto
#         - Interazione

# %% [markdown]
# ## Esempi
# ### Amazon Shopping
# **Dati**: Storico acquisti, Informazioni demografiche. <br>
# **Analisi**: Potenziali acquisti. <br>
# **Prodotto**: Plubbicità Ad-Hoc. <br>
# ### Uber
# **Dati**: Storico Corse, Traffico, Richieste. <br>
# **Analisi**: Picchi di domanda, Variazione della disponibilità dei driver. <br>
# **Prodotto**: Aggiustamento del prezzo della corsa. <br>
# ### Netflix
# **Dati**: Contenuti guardati, Interazione con la piattaforma. <br>
# **Analisi**: Titoli preferiti, Livello di attenzione, Pattern di visualizzazione. <br>
# **Prodotto**: Titotli da consigliare, Prodotto su cui investire. <br>

# %% [markdown]
# ## Web Data Mining
# Il Web è la più grande sorgente di informazione pubblicamente accessibile al mondo:
# - **Enorme quantità di dati**: in continua crescita, info su quasi qualunque cosa
# - **Eterogeneità del formato dei dati**: tabelle, pagine web (immagini, audio, video)
# - **Eterogeneità dell'informazione**
# - **Rumore e ridondanza** → (content mining), adattabilità del contenuto
# - **Dinamico**: info cambia nel tempo → monitoraggio cambiamenti
# - **Società virtuale**: forum, blog, siti di review, reti sociali → opinion mining, social network analysis
#
# ## Esempio:
# **[Twitter Analysis](http://bigdata.stratebi.com)** <br>
# **Problema**: Predizione gusti degli utenti. <br>
# **Misura di prestazione**: Percentuale tweet correttamente analizzati. <br>
# **Esperienza**: Utenti già profilati e relazioni già osservate. <br>

# %% [markdown]
# # Dataset
# Un dataset è una collezione di dati. Nel caso di dati tabulari, un set di dati corrisponde a una o più tabelle di un database, dove ogni colonna di una tabella rappresenta una particolare variabile, e ogni riga corrisponde a un dato record del set di dati in questione.

# %% [markdown]
# ## Risorse:
# - [Google Datasets](https://research.google/tools/datasets)
# - [Kaggle](https:www.kaggle.com)
#     - Competizioni:
#         - Esempi di problemi reali
#         - Compenso economico per il vincitore
#         - Esempi:
#             - [H&M](https://www.kaggle.com/c/h-and-m-personalized-fashion-recommendations)
#             - [Titanic](https://www.kaggle.com/c/titanic)
#             - [G-Research Crypto Forecasting](https://www.kaggle.com/c/g-research-crypto-forecasting)
#             - [Feedback Prize - Evaluating Student Writing](https://www.kaggle.com/c/feedback-prize-2021)

# %% [markdown]
# # [Pandas](https://pandas.pydata.org) Tutorial

# %% [markdown]
# **Cos'è Pandas?**
# - Pandas è una libreria Python scritta per la manipolazione e l'analisi dei dati.
# - DataFrame Object per la manipolazione dei dati con indicizzazione.
# - Strumenti per leggere e scrivere dati tra strutture dati e diversi formati.
# - Fusione e unione di data sets
# - Inserimento e cancellazione di colonne e righe
# - Allineamento dei dati e gestione integrata dei dati mancanti
# - La libreria è altamente ottimizzata per le prestazioni, con codice scritto in Cython o C.

# %% [markdown]
# # Parte 1 - Introduzione
#
# Il primo passaggio è importare Pandas:

# %%
import pandas as pd

# %% [markdown]
# Dopodiché bisogna importare il nostro primo Dataset:
# [Avocado Price](https://www.kaggle.com/neuromusic/avocado-prices?select=avocado.csv)

# %%
avocado_df = pd.read_csv("../datasets/avocado.csv")

# %% [markdown]
# Per poter visualizzare il nostro dataset abbiamo più possivilità:
# - Per "intero"
# - Head or Tail

# %%
avocado_df.head()
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1           1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2           2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3           3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4           4  2015-11-29          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
# 4   75.78     6183.95     5986.26      197.69          0.0  conventional
#
#    year  region
# 0  2015  Albany
# 1  2015  Albany
# 2  2015  Albany
# 3  2015  Albany
# 4  2015  Albany

# %% [markdown]
# Possiamo farci restituire una porzione del dataset:

# %%
avocado_df["AveragePrice"]
# Out:
# 0        1.33
# 1        1.35
# 2        0.93
# 3        1.08
# 4        1.28
#          ...
# 18244    1.63
# 18245    1.71
# 18246    1.87
# 18247    1.93
# 18248    1.62
# Name: AveragePrice, Length: 18249, dtype: float64

# %% [markdown]
# Inoltre possiamo aggiungere una condizione:

# %%
avocado_df[avocado_df["AveragePrice"] > 1.0]
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046      4225  \
# 0               0  2015-12-27          1.33      64236.62  1036.74  54454.85
# 1               1  2015-12-20          1.35      54876.98   674.28  44638.81
# 3               3  2015-12-06          1.08      78992.15  1132.00  71976.41
# 4               4  2015-11-29          1.28      51039.60   941.48  43838.39
# 5               5  2015-11-22          1.26      55979.78  1184.27  48067.99
# ...           ...         ...           ...           ...      ...       ...
# 18244           7  2018-02-04          1.63      17074.83  2046.96   1529.20
# 18245           8  2018-01-28          1.71      13888.04  1191.70   3431.50
# 18246           9  2018-01-21          1.87      13766.76  1191.92   2452.79
# 18247          10  2018-01-14          1.93      16205.22  1527.63   2981.04
# 18248          11  2018-01-07          1.62      17489.58  2894.77   2356.13
#
#          4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0       48.16     8696.87     8603.62       93.25          0.0  conventional
# 1       58.33     9505.56     9408.07       97.49          0.0  conventional
# 3       72.58     5811.16     5677.40      133.76          0.0  conventional
# 4       75.78     6183.95     5986.26      197.69          0.0  conventional
# 5       43.61     6683.91     6556.47      127.44          0.0  conventional
# ...       ...         ...         ...         ...          ...           ...
# 18244    0.00    13498.67    13066.82      431.85          0.0       organic
# 18245    0.00     9264.84     8940.04      324.80          0.0       organic
# 18246  727.94     9394.11     9351.80       42.31          0.0       organic
# 18247  727.01    10969.54    10919.54       50.00          0.0       organic
# 18248  224.53    12014.15    11988.14       26.01          0.0       organic
#
#        year            region
# 0      2015            Albany
# 1      2015            Albany
# 3      2015            Albany
# 4      2015            Albany
# 5      2015            Albany
# ...     ...               ...
# 18244  2018  WestTexNewMexico
# 18245  2018  WestTexNewMexico
# 18246  2018  WestTexNewMexico
# 18247  2018  WestTexNewMexico
# 18248  2018  WestTexNewMexico
#
# [15286 rows x 14 columns]

# %% [markdown]
# ## ESERICIZIO 1
#
# **Estrarre una porzione del dataset per la quale la regione è uguale a "Boston"**

# %%
boston_avocado_df = avocado_df[ avocado_df["region"] == "Boston" ]

# %% [markdown]
# Andiamo a verificare il risultato:

# %%
boston_avocado_df.head()
# Out:
#      Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 208           0  2015-12-27          1.13     450816.39  3886.27  346964.70
# 209           1  2015-12-20          1.07     489802.88  4912.37  390100.99
# 210           2  2015-12-13          1.01     549945.76  4641.02  455362.38
# 211           3  2015-12-06          1.02     488679.31  5126.32  407520.22
# 212           4  2015-11-29          1.19     350559.81  3609.25  272719.08
#
#          4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 208  13952.56    86012.86    85913.60       99.26          0.0  conventional
# 209   5887.72    88901.80    88768.47      133.33          0.0  conventional
# 210    219.40    89722.96    89523.38      199.58          0.0  conventional
# 211    142.99    75889.78    75666.22      223.56          0.0  conventional
# 212    105.86    74125.62    73864.52      261.10          0.0  conventional
#
#      year  region
# 208  2015  Boston
# 209  2015  Boston
# 210  2015  Boston
# 211  2015  Boston
# 212  2015  Boston

# %% [markdown]
# Il dataframe dovrebbe essere indicizzato da un elenento.

# %%
boston_avocado_df.index
# Out:
# Int64Index([  208,   209,   210,   211,   212,   213,   214,   215,   216,
#               217,
#             ...
#             17651, 17652, 17653, 17654, 17655, 17656, 17657, 17658, 17659,
#             17660],
#            dtype='int64', length=338)

# %% [markdown]
# Nel nostro caso l'indice è senza significato, bisognerebbe trovare un dato che mette in relazione tutte le righe!<br>

# %%
boston_avocado_df.set_index("Date")
# Out:
#             Unnamed: 0  AveragePrice  Total Volume     4046       4225  \
# Date
# 2015-12-27           0          1.13     450816.39  3886.27  346964.70
# 2015-12-20           1          1.07     489802.88  4912.37  390100.99
# 2015-12-13           2          1.01     549945.76  4641.02  455362.38
# 2015-12-06           3          1.02     488679.31  5126.32  407520.22
# 2015-11-29           4          1.19     350559.81  3609.25  272719.08
# ...                ...           ...           ...      ...        ...
# 2018-02-04           7          1.83      28934.01     9.14    2504.27
# 2018-01-28           8          1.72      30846.35    14.65    1628.45
# 2018-01-21           9          1.82      26704.98    60.87    2647.48
# 2018-01-14          10          1.73      29468.36    12.77    2380.23
# 2018-01-07          11          1.91      30096.00    14.46    2704.48
#
#                 4770  Total Bags  Small Bags  Large Bags  XLarge Bags  \
# Date
# 2015-12-27  13952.56    86012.86    85913.60       99.26          0.0
# 2015-12-20   5887.72    88901.80    88768.47      133.33          0.0
# 2015-12-13    219.40    89722.96    89523.38      199.58          0.0
# 2015-12-06    142.99    75889.78    75666.22      223.56          0.0
# 2015-11-29    105.86    74125.62    73864.52      261.10          0.0
# ...              ...         ...         ...         ...          ...
# 2018-02-04      3.66    26416.94    20660.94     5756.00          0.0
# 2018-01-28      0.00    29203.25    27876.23     1327.02          0.0
# 2018-01-21      0.00    23996.63    21985.03     2011.60          0.0
# 2018-01-14      0.00    27075.36    23926.76     3148.60          0.0
# 2018-01-07      0.00    27377.06    25121.53     2255.53          0.0
#
#                     type  year  region
# Date
# 2015-12-27  conventional  2015  Boston
# 2015-12-20  conventional  2015  Boston
# 2015-12-13  conventional  2015  Boston
# 2015-12-06  conventional  2015  Boston
# 2015-11-29  conventional  2015  Boston
# ...                  ...   ...     ...
# 2018-02-04       organic  2018  Boston
# 2018-01-28       organic  2018  Boston
# 2018-01-21       organic  2018  Boston
# 2018-01-14       organic  2018  Boston
# 2018-01-07       organic  2018  Boston
#
# [338 rows x 13 columns]

# %%
boston_avocado_df.head()
# Out:
#      Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 208           0  2015-12-27          1.13     450816.39  3886.27  346964.70
# 209           1  2015-12-20          1.07     489802.88  4912.37  390100.99
# 210           2  2015-12-13          1.01     549945.76  4641.02  455362.38
# 211           3  2015-12-06          1.02     488679.31  5126.32  407520.22
# 212           4  2015-11-29          1.19     350559.81  3609.25  272719.08
#
#          4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 208  13952.56    86012.86    85913.60       99.26          0.0  conventional
# 209   5887.72    88901.80    88768.47      133.33          0.0  conventional
# 210    219.40    89722.96    89523.38      199.58          0.0  conventional
# 211    142.99    75889.78    75666.22      223.56          0.0  conventional
# 212    105.86    74125.62    73864.52      261.10          0.0  conventional
#
#      year  region
# 208  2015  Boston
# 209  2015  Boston
# 210  2015  Boston
# 211  2015  Boston
# 212  2015  Boston

# %% [markdown]
# Problema uguale a prima, se l'oggetto dataframe non viene ridefinito in una variabile il contenuto sarà perso a meno che:

# %%
boston_avocado_df.set_index("Date", inplace = True) #inpace

# %%
boston_avocado_df.head()
# Out:
#             Unnamed: 0  AveragePrice  Total Volume     4046       4225  \
# Date
# 2015-12-27           0          1.13     450816.39  3886.27  346964.70
# 2015-12-20           1          1.07     489802.88  4912.37  390100.99
# 2015-12-13           2          1.01     549945.76  4641.02  455362.38
# 2015-12-06           3          1.02     488679.31  5126.32  407520.22
# 2015-11-29           4          1.19     350559.81  3609.25  272719.08
#
#                 4770  Total Bags  Small Bags  Large Bags  XLarge Bags  \
# Date
# 2015-12-27  13952.56    86012.86    85913.60       99.26          0.0
# 2015-12-20   5887.72    88901.80    88768.47      133.33          0.0
# 2015-12-13    219.40    89722.96    89523.38      199.58          0.0
# 2015-12-06    142.99    75889.78    75666.22      223.56          0.0
# 2015-11-29    105.86    74125.62    73864.52      261.10          0.0
#
#                     type  year  region
# Date
# 2015-12-27  conventional  2015  Boston
# 2015-12-20  conventional  2015  Boston
# 2015-12-13  conventional  2015  Boston
# 2015-12-06  conventional  2015  Boston
# 2015-11-29  conventional  2015  Boston

# %% [markdown]
# Facciamo un plot dei nostri dati:

# %%
boston_avocado_df.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# Meglio fare il plot di un elemto alla volta!

# %%
boston_avocado_df["AveragePrice"].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# **Problema**: Pandas non riconosce che sono date
#
# Bisogna riassegnare l'indice con un nuovo tipo -> datetime

# %%
boston_avocado_df.index = pd.to_datetime(boston_avocado_df.index)
boston_avocado_df.head()
# Out:
#             Unnamed: 0  AveragePrice  Total Volume     4046       4225  \
# Date
# 2015-12-27           0          1.13     450816.39  3886.27  346964.70
# 2015-12-20           1          1.07     489802.88  4912.37  390100.99
# 2015-12-13           2          1.01     549945.76  4641.02  455362.38
# 2015-12-06           3          1.02     488679.31  5126.32  407520.22
# 2015-11-29           4          1.19     350559.81  3609.25  272719.08
#
#                 4770  Total Bags  Small Bags  Large Bags  XLarge Bags  \
# Date
# 2015-12-27  13952.56    86012.86    85913.60       99.26          0.0
# 2015-12-20   5887.72    88901.80    88768.47      133.33          0.0
# 2015-12-13    219.40    89722.96    89523.38      199.58          0.0
# 2015-12-06    142.99    75889.78    75666.22      223.56          0.0
# 2015-11-29    105.86    74125.62    73864.52      261.10          0.0
#
#                     type  year  region
# Date
# 2015-12-27  conventional  2015  Boston
# 2015-12-20  conventional  2015  Boston
# 2015-12-13  conventional  2015  Boston
# 2015-12-06  conventional  2015  Boston
# 2015-11-29  conventional  2015  Boston

# %% [markdown]
# Proviamo a rifare il plot!

# %%
boston_avocado_df["AveragePrice"].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# **Problema**: Troppe oscillazione, conviene utilizzare una media mobile

# %%
boston_avocado_df.tail()
# Out:
#             Unnamed: 0  AveragePrice  Total Volume   4046     4225  4770  \
# Date
# 2018-02-04           7          1.83      28934.01   9.14  2504.27  3.66
# 2018-01-28           8          1.72      30846.35  14.65  1628.45  0.00
# 2018-01-21           9          1.82      26704.98  60.87  2647.48  0.00
# 2018-01-14          10          1.73      29468.36  12.77  2380.23  0.00
# 2018-01-07          11          1.91      30096.00  14.46  2704.48  0.00
#
#             Total Bags  Small Bags  Large Bags  XLarge Bags     type  year  \
# Date
# 2018-02-04    26416.94    20660.94     5756.00          0.0  organic  2018
# 2018-01-28    29203.25    27876.23     1327.02          0.0  organic  2018
# 2018-01-21    23996.63    21985.03     2011.60          0.0  organic  2018
# 2018-01-14    27075.36    23926.76     3148.60          0.0  organic  2018
# 2018-01-07    27377.06    25121.53     2255.53          0.0  organic  2018
#
#             region
# Date
# 2018-02-04  Boston
# 2018-01-28  Boston
# 2018-01-21  Boston
# 2018-01-14  Boston
# 2018-01-07  Boston

# %%
boston_avocado_df.index
# Out:
# DatetimeIndex(['2015-12-27', '2015-12-20', '2015-12-13', '2015-12-06',
#                '2015-11-29', '2015-11-22', '2015-11-15', '2015-11-08',
#                '2015-11-01', '2015-10-25',
#                ...
#                '2018-03-11', '2018-03-04', '2018-02-25', '2018-02-18',
#                '2018-02-11', '2018-02-04', '2018-01-28', '2018-01-21',
#                '2018-01-14', '2018-01-07'],
#               dtype='datetime64[ns]', name='Date', length=338, freq=None)

# %%
boston_avocado_df.sort_index(inplace=True)
boston_avocado_df["AveragePrice"].rolling(25).mean().plot()
# Out:
# /opt/homebrew/Caskroom/miniforge/base/envs/sim/lib/python3.9/site-packages/pandas/core/frame.py:6393: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().sort_index(
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# Questa colonna potrebbe essere utile in futuro! Come facciamo a renderla una colonna del dataset?

# %%
boston_avocado_df["price25ma"] = boston_avocado_df["AveragePrice"].rolling(25).mean()
# Out:
# /var/folders/lr/d8nq9v9x525g290h3kqjrbgw0000gn/T/ipykernel_95973/2649828202.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   boston_avocado_df["price25ma"] = boston_avocado_df["AveragePrice"].rolling(25).mean()

# %%
boston_avocado_df.head()
# Out:
#             Unnamed: 0  AveragePrice  Total Volume     4046       4225  \
# Date
# 2015-01-04          51          1.02     491738.00  7193.87  396752.18
# 2015-01-04          51          1.83       2192.13     8.66     939.43
# 2015-01-11          50          1.10     437771.89  5548.11  320577.36
# 2015-01-11          50          1.94       2217.82    12.82     956.07
# 2015-01-18          49          1.23     401331.33  4383.76  287778.52
#
#               4770  Total Bags  Small Bags  Large Bags  XLarge Bags  \
# Date
# 2015-01-04  128.82    87663.13    87406.84      256.29          0.0
# 2015-01-04    0.00     1244.04     1244.04        0.00          0.0
# 2015-01-11  121.81   111524.61   111192.88      331.73          0.0
# 2015-01-11    0.00     1248.93     1248.93        0.00          0.0
# 2015-01-18  132.53   109036.52   108668.74      367.78          0.0
#
#                     type  year  region  price25ma
# Date
# 2015-01-04  conventional  2015  Boston        NaN
# 2015-01-04       organic  2015  Boston        NaN
# 2015-01-11  conventional  2015  Boston        NaN
# 2015-01-11       organic  2015  Boston        NaN
# 2015-01-18  conventional  2015  Boston        NaN

# %%
boston_avocado_df.head(26)
# Out:
#             Unnamed: 0  AveragePrice  Total Volume     4046       4225  \
# Date
# 2015-01-04          51          1.02     491738.00  7193.87  396752.18
# 2015-01-04          51          1.83       2192.13     8.66     939.43
# 2015-01-11          50          1.10     437771.89  5548.11  320577.36
# 2015-01-11          50          1.94       2217.82    12.82     956.07
# 2015-01-18          49          1.23     401331.33  4383.76  287778.52
# 2015-01-18          49          2.00       2209.34     4.22     834.34
# 2015-01-25          48          1.17     409343.56  4730.77  288094.65
# 2015-01-25          48          2.01       1948.28     3.14     760.39
# 2015-02-01          47          1.22     490022.14  6082.88  373452.06
# 2015-02-01          47          1.78       2943.85    12.18    1308.94
# 2015-02-08          46          1.04     609985.34  7653.19  495731.70
# 2015-02-08          46          1.91       3098.29    15.18     948.71
# 2015-02-15          45          1.20     399883.99  3794.97  281106.45
# 2015-02-15          45          1.91       2271.95    18.98     678.93
# 2015-02-22          44          1.74       3325.89    75.83    1062.64
# 2015-02-22          44          1.23     355432.28  3232.68  251341.30
# 2015-03-01          43          1.85       3024.12     8.47     932.50
# 2015-03-01          43          1.11     485736.10  4106.42  383573.77
# 2015-03-08          42          1.91       2566.90    29.07     945.32
# 2015-03-08          42          1.17     408403.96  3425.53  290512.65
# 2015-03-15          41          1.99       1965.57    19.04     904.23
# 2015-03-15          41          1.25     417750.36  6085.75  308996.70
# 2015-03-22          40          1.94       2763.26     6.36    1119.46
# 2015-03-22          40          1.18     453173.22  5956.18  344396.92
# 2015-03-29          39          1.98       2121.96    22.27     745.34
# 2015-03-29          39          1.19     453631.25  3619.31  339299.30
#
#               4770  Total Bags  Small Bags  Large Bags  XLarge Bags  \
# Date
# 2015-01-04  128.82    87663.13    87406.84      256.29          0.0
# 2015-01-04    0.00     1244.04     1244.04        0.00          0.0
# 2015-01-11  121.81   111524.61   111192.88      331.73          0.0
# 2015-01-11    0.00     1248.93     1248.93        0.00          0.0
# 2015-01-18  132.53   109036.52   108668.74      367.78          0.0
# 2015-01-18    0.00     1370.78     1370.78        0.00          0.0
# 2015-01-25   45.98   116472.16   115538.05      934.11          0.0
# 2015-01-25    0.00     1184.75     1184.75        0.00          0.0
# 2015-02-01  272.81   110214.39   109900.93      313.46          0.0
# 2015-02-01    0.00     1622.73     1622.73        0.00          0.0
# 2015-02-08  383.73   106216.72   105403.38      813.34          0.0
# 2015-02-08    0.00     2134.40     2134.40        0.00          0.0
# 2015-02-15  143.41   114839.16   114283.61      555.55          0.0
# 2015-02-15    0.00     1574.04     1574.04        0.00          0.0
# 2015-02-22    0.00     2187.42     2187.42        0.00          0.0
# 2015-02-22  142.33   100715.97   100498.19      217.78          0.0
# 2015-03-01    0.00     2083.15     2083.15        0.00          0.0
# 2015-03-01  192.98    97862.93    97423.17      439.76          0.0
# 2015-03-08    0.00     1592.51     1592.51        0.00          0.0
# 2015-03-08   78.96   114386.82   113811.26      575.56          0.0
# 2015-03-15    0.00     1042.30     1042.30        0.00          0.0
# 2015-03-15  111.59   102556.32   101931.87      624.45          0.0
# 2015-03-22    0.00     1637.44     1627.44       10.00          0.0
# 2015-03-22  155.94   102664.18   102204.17      460.01          0.0
# 2015-03-29    0.00     1354.35     1314.35       40.00          0.0
# 2015-03-29  151.36   110561.28   108838.11     1723.17          0.0
#
#                     type  year  region  price25ma
# Date
# 2015-01-04  conventional  2015  Boston        NaN
# 2015-01-04       organic  2015  Boston        NaN
# 2015-01-11  conventional  2015  Boston        NaN
# 2015-01-11       organic  2015  Boston        NaN
# 2015-01-18  conventional  2015  Boston        NaN
# 2015-01-18       organic  2015  Boston        NaN
# 2015-01-25  conventional  2015  Boston        NaN
# 2015-01-25       organic  2015  Boston        NaN
# 2015-02-01  conventional  2015  Boston        NaN
# 2015-02-01       organic  2015  Boston        NaN
# 2015-02-08  conventional  2015  Boston        NaN
# 2015-02-08       organic  2015  Boston        NaN
# 2015-02-15  conventional  2015  Boston        NaN
# 2015-02-15       organic  2015  Boston        NaN
# 2015-02-22       organic  2015  Boston        NaN
# 2015-02-22  conventional  2015  Boston        NaN
# 2015-03-01       organic  2015  Boston        NaN
# 2015-03-01  conventional  2015  Boston        NaN
# 2015-03-08       organic  2015  Boston        NaN
# 2015-03-08  conventional  2015  Boston        NaN
# 2015-03-15       organic  2015  Boston        NaN
# 2015-03-15  conventional  2015  Boston        NaN
# 2015-03-22       organic  2015  Boston        NaN
# 2015-03-22  conventional  2015  Boston        NaN
# 2015-03-29       organic  2015  Boston     1.5484
# 2015-03-29  conventional  2015  Boston     1.5552

# %% [markdown]
# NaN = Not A Number

# %% [markdown]
# Bisognerà rimuovere tutti le riche che sono uguali a NaN

# %%
boston_avocado_df.dropna().head(3)
# Out:
#             Unnamed: 0  AveragePrice  Total Volume     4046       4225  \
# Date
# 2015-03-29          39          1.98       2121.96    22.27     745.34
# 2015-03-29          39          1.19     453631.25  3619.31  339299.30
# 2015-04-05          38          1.27     449818.01  3657.54  330424.74
#
#               4770  Total Bags  Small Bags  Large Bags  XLarge Bags  \
# Date
# 2015-03-29    0.00     1354.35     1314.35       40.00         0.00
# 2015-03-29  151.36   110561.28   108838.11     1723.17         0.00
# 2015-04-05   99.92   115635.81   113541.34     1948.64       145.83
#
#                     type  year  region  price25ma
# Date
# 2015-03-29       organic  2015  Boston     1.5484
# 2015-03-29  conventional  2015  Boston     1.5552
# 2015-04-05  conventional  2015  Boston     1.5328

# %% [markdown]
# Possiamo estrarre dal dataframe colonne con diversi formati:
# - Array
# - Liste

# %%
avocado_df["region"].values #.to_lilst()
# Out:
# array(['Albany', 'Albany', 'Albany', ..., 'WestTexNewMexico',
#        'WestTexNewMexico', 'WestTexNewMexico'], dtype=object)

# %%
avocado_df["region"].values.tolist()
set(avocado_df["region"].values.tolist())
list(set(avocado_df["region"].values.tolist()))
#set restituisce un array
# Out:
# ['HarrisburgScranton',
#  'HartfordSpringfield',
#  'NewYork',
#  'RichmondNorfolk',
#  'Denver',
#  'WestTexNewMexico',
#  'Seattle',
#  'West',
#  'Columbus',
#  'BaltimoreWashington',
#  'Atlanta',
#  'Midsouth',
#  'Spokane',
#  'DallasFtWorth',
#  'Charlotte',
#  'Sacramento',
#  'NewOrleansMobile',
#  'SouthCarolina',
#  'MiamiFtLauderdale',
#  'Albany',
#  'SanFrancisco',
#  'BuffaloRochester',
#  'Detroit',
#  'Boston',
#  'PhoenixTucson',
#  'Louisville',
#  'Houston',
#  'CincinnatiDayton',
#  'California',
#  'Boise',
#  'LosAngeles',
#  'Southeast',
#  'SanDiego',
#  'Northeast',
#  'NorthernNewEngland',
#  'Roanoke',
#  'SouthCentral',
#  'Philadelphia',
#  'LasVegas',
#  'Tampa',
#  'Indianapolis',
#  'RaleighGreensboro',
#  'Chicago',
#  'GrandRapids',
#  'StLouis',
#  'GreatLakes',
#  'Orlando',
#  'Nashville',
#  'Pittsburgh',
#  'Plains',
#  'Syracuse',
#  'Portland',
#  'TotalUS',
#  'Jacksonville']

# %% [markdown]
# Oppure più semplicemente:

# %%
# Pandas ha molto spesso ha già delle funzione che sono più veloci si qualsiasi altra funzione che voi potreste implementare
avocado_df["region"].unique()
# Out:
# array(['Albany', 'Atlanta', 'BaltimoreWashington', 'Boise', 'Boston',
#        'BuffaloRochester', 'California', 'Charlotte', 'Chicago',
#        'CincinnatiDayton', 'Columbus', 'DallasFtWorth', 'Denver',
#        'Detroit', 'GrandRapids', 'GreatLakes', 'HarrisburgScranton',
#        'HartfordSpringfield', 'Houston', 'Indianapolis', 'Jacksonville',
#        'LasVegas', 'LosAngeles', 'Louisville', 'MiamiFtLauderdale',
#        'Midsouth', 'Nashville', 'NewOrleansMobile', 'NewYork',
#        'Northeast', 'NorthernNewEngland', 'Orlando', 'Philadelphia',
#        'PhoenixTucson', 'Pittsburgh', 'Plains', 'Portland',
#        'RaleighGreensboro', 'RichmondNorfolk', 'Roanoke', 'Sacramento',
#        'SanDiego', 'SanFrancisco', 'Seattle', 'SouthCarolina',
#        'SouthCentral', 'Southeast', 'Spokane', 'StLouis', 'Syracuse',
#        'Tampa', 'TotalUS', 'West', 'WestTexNewMexico'], dtype=object)
